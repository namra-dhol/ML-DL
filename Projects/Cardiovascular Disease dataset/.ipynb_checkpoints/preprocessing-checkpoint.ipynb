# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cardio_train.csv',sep=';')
demo = df.copy()

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.duplicated().any()
# Out:
# False

# %%
df2 = df.copy()
df2.drop(columns=['id'], inplace =True)

df2['age'] = (df2['age'] / 365).astype('int')
# 
df2['gender'] = df2['gender'].replace({1:'M', 2:'H'}).astype('category')

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int32
#  1   gender       70000 non-null  category
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: category(1), float64(1), int32(1), int64(9)
# memory usage: 5.7 MB

# %%
df2.head()
# Out:
#    age gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50      H     168    62.0    110     80            1     1      0     0
# 1   55      M     156    85.0    140     90            3     1      0     0
# 2   51      M     165    64.0    130     70            3     1      0     0
# 3   48      H     169    82.0    150    100            1     1      0     0
# 4   47      M     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df2.describe()
# Out:
#                 age        height        weight         ap_hi         ap_lo  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      52.840671    164.359229     74.205690    128.817286     96.630414
# std        6.766774      8.210126     14.395757    154.011419    188.472530
# min       29.000000     55.000000     10.000000   -150.000000    -70.000000
# 25%       48.000000    159.000000     65.000000    120.000000     80.000000
# 50%       53.000000    165.000000     72.000000    120.000000     80.000000
# 75%       58.000000    170.000000     82.000000    140.000000     90.000000
# max       64.000000    250.000000    200.000000  16020.000000  11000.000000
#
#         cholesterol          gluc         smoke          alco        active  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.366871      1.226457      0.088129      0.053771      0.803729
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int32
#  1   gender       70000 non-null  category
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: category(1), float64(1), int32(1), int64(9)
# memory usage: 5.7 MB

# %%
df2['Pulse_Pressure'] = (df2['ap_hi'] - df2['ap_lo'])
df2
# Out:
#        age gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50      H     168    62.0    110     80            1     1      0
# 1       55      M     156    85.0    140     90            3     1      0
# 2       51      M     165    64.0    130     70            3     1      0
# 3       48      H     169    82.0    150    100            1     1      0
# 4       47      M     156    56.0    100     60            1     1      0
# ...    ...    ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52      H     168    76.0    120     80            1     1      1
# 69996   61      M     158   126.0    140     90            2     2      0
# 69997   52      H     183   105.0    180     90            3     1      0
# 69998   61      M     163    72.0    135     80            1     2      0
# 69999   56      M     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  Pulse_Pressure
# ...

# %%
# BMI Column i will use it to calculate the risk of cardiovescular diesease. 
df2["BMI"] = (df2["weight"] / ((df2["height"] / 100) ** 2))
df2['BMI']
# Out:
# 0        21.967120
# 1        34.927679
# 2        23.507805
# 3        28.710479
# 5        29.384676
#            ...
# 69991    28.479886
# 69993    23.661439
# 69995    26.927438
# 69998    27.099251
# 69999    24.913495
# Name: BMI, Length: 58415, dtype: float64

# %%
# | BP Type               | Minimum | Maximum | Why?                                                    |
# | --------------------- | ------- | ------- | ------------------------------------------------------- |
# | **Diastolic (ap_lo)** | 40      | 140     | below 40 = error, above 140 = extremely rare/impossible |
# | **Systolic (ap_hi)**  | 70      | 240     | below 70 = error, above 240 = extremely abnormal        |
# 2. Remove records with extreme low and high BP values based on reasonable clinical ranges.
# Minimum reasonable diastolic pressure (e.g., >= 40)
# Minimum reasonable systolic pressure (e.g., >= 70)
# Maximum reasonable diastolic pressure (e.g., <= 140)
# Maximum reasonable systolic pressure (e.g., <= 240)

# %%
df2 = df2[
    (df2['ap_lo'] >= 40) & (df2['ap_lo'] <= 140) &
    (df2['ap_hi'] >= 70) & (df2['ap_hi'] <= 240)
]

# %%
df2
# Out:
#        age gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50      H     168    62.0    110     80            1     1      0
# 1       55      M     156    85.0    140     90            3     1      0
# 2       51      M     165    64.0    130     70            3     1      0
# 3       48      H     169    82.0    150    100            1     1      0
# 4       47      M     156    56.0    100     60            1     1      0
# ...    ...    ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52      H     168    76.0    120     80            1     1      1
# 69996   61      M     158   126.0    140     90            2     2      0
# 69997   52      H     183   105.0    180     90            3     1      0
# 69998   61      M     163    72.0    135     80            1     2      0
# 69999   56      M     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  Pulse_Pressure
# ...

# %%
# cols_to_check = ['height', 'weight', 'ap_hi', 'ap_lo', 'age', 'Pulse_Pressure']

# data_before = df2.copy()

# # IQR Outlier Removal
# for col in cols_to_check:
#     Q1 = df2[col].quantile(0.25)
#     Q3 = df2[col].quantile(0.75)
#     IQR = Q3 - Q1

#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
    
#     df2 = df2[(df2[col] >= lower_bound) & (df2[col] <= upper_bound)]

# # After-cleaning copy
# data_after = df2.copy()

# # PLOTTING FUNCTION
# def plot_boxplots(df, title):
#     fig, axes = plt.subplots(2, 3, figsize=(18, 10))
#     fig.suptitle(title, fontsize=18)

#     for ax, col in zip(axes.flatten(), cols_to_check):
#         sns.boxplot(y=df[col], ax=ax)
#         ax.set_title(col)

#     plt.tight_layout(rect=[0, 0, 1, 0.96])
#     plt.show()

# # SHOW PLOTS
# plot_boxplots(data_before, "Before Outlier Removal (IQR)")
# plot_boxplots(data_after, "After Outlier Removal (IQR)")
